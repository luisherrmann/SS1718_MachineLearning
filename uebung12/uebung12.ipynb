# %% [markdown]
# <center>
# <h1>Mustererkennung und Machine Learning</h1>
#
# <h3> Wintersemester 2017/2018, 12th Exercise Sheet</h3>
# <h4>Konstantin Jaehne, Luis Herrmann; Dozent: Raúl Rojas</h4>
#
# <hr style='height:1px'>
# </center>

# %% [markdown]
# # Exercise 1

# %% [markdown]
# As usual, we read in the digit dataset fron the respective files:

# %%
# %matplotlib inline
import sys
import numpy as np
import numpy.random as nprd
import random as rd
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from IPython.display import display, HTML

def readfile(filename):
    """Opens file with given filename and reads in data line after line into a numpy array"""
    data = [[] for i in range(10)]
    f = open(filename)
    for line in f:
        ls = line.split(' ')
        digit = int(float(ls[0]))
        sample = np.array([float(val) for val in ls[1:257]])
        data[digit].append(sample)
    f.close()
    return(list(map(lambda x: np.vstack(x), data)))
    
def visualize(data, i, shape):
    """
    For a list of numpy arrays with greyscale values, visualizes the greyscale data 
    creating a greyscale plot of the reshaped 16x16 numpy array
    """
    plt.gray()
    plt.imshow(data[i].reshape(shape))
    
train = readfile('../zip.train')
test = readfile('../zip.test')

# %% [markdown]
# Again, we visualize a sample feature vector from the data to make sure the data makes sense.

# %%
visualize(train[3], 0, [16,16])

# %% [markdown]
# We now implement a neurol network class, which allows for training using forward-feeding and backpropagation and classification

# %%
train[0].shape
# Out:
# (1194, 256)

# %% [markdown]
# We then perform training on the digit dataset for different layer depths and perceptron counts and plot the classification error for the training data at every iteration step:

# %%
class NeuronNetwork:
    def __init__(self, data = None, labels = None, **kwargs):
        """
        data (optional):
            Type: List/Tuple
            A list/tuple (d1,..., dm), where di is a matrix in which each row is a feature vector assigned to class i.
        labels (optinal):
            Type: List/Tuple
            A list/tuple (i1,..., im) of m printable identifiers associated with each class.
        itlimit (optional):
            Type: Integer
            Maximum number of iterations, before training is forcefully terminated.
        tol (optional):
            Type: Float
            Minimum rate of improvement that is acceptable. If improvement drops below tolerance, stop descent.
        pcount (optional):
            Type: Integer
            Number of perceptrons to be used in each hidden layer.
        lcount (optional):
            Type: Integer
            Number of hidden layers to be used.
        interactive (optional):
            Type: Boolean
            If True will plot error rate in real time.
        ret (optional):
            Type: Boolean
            If True will return a list l where l[i] is the error of the i-th iteration
        beta (optional):
            Type: Float
            The learning rate used in the gradient descent.
        afunc (optional):
            Type: String
            A string determining the activation function to be used. Possible functions are:
            'sigmoid', 'relu'
        """
        self.labels = labels
        if(not(data is None)):
            self.train(data, **kwargs)
        
    def train(self, data, 
              itlimit=1000, 
              tol=1e-19, 
              pcount=None, 
              lcount=1, 
              interactive=False, 
              ret=True, 
              beta=1e-3,
              afunc='relu'):
        
        if(self.labels is None):
            self.labels = range(len(data))
        self.beta = beta
        functions = {'sigmoid' : self.sigmoid, 'relu' : self.relu}
        if(afunc in functions):
            self.afunc = functions[afunc]
        else:
            self.afunc = self.relu
        
        x = np.vstack(data)
        #Normalize data
        self.mean = np.mean(x, axis=0)[np.newaxis,:] 
        self.variance = np.var(x, axis=0)[np.newaxis,:]
        self.variance[np.where(self.variance == 0)] = 1
        x = self.normalize(x)
        #Create label vector
        n = x.shape[1]
        m = len(self.labels)
        self.y = np.zeros([x.shape[0], m])
        comp = np.zeros(x.shape[0])
        low = 0
        for i in range(len(data)):
            high = low + data[i].shape[0]
            self.y[low:high,i] = 1
            comp[low:high] = i
            low = high
        
        o = np.hstack([x, np.repeat(1, x.shape[0])[:,np.newaxis]])
        #Initialize random hidden layer and output layer weights: (Use Glorot initialization)
        if(pcount is None):
            pcount = x.shape[0]
        self.W = [self.genrdweights(n+1, pcount)] + [self.genrdweights(pcount+1, pcount) for i in range(lcount-1)] + [self.genrdweights(pcount+1, m)]
        #Batch normalization parameter initialization:
        self.bngamma = nprd.random(lcount)
        self.bnbeta = nprd.random(lcount)
        self.layerparams = [None for i in range(lcount)]
        #Initialize iteration parameters:
        t = 0
        #Initialize interactive plot
        if(interactive):
            plt.ion()
            fig = plt.figure()
            ax = fig.add_subplot(111)
        err = []

        while(t < itlimit):
            #Calculate hidden-layer and output-layer output:
            ol = self.feedforward(o)
            #Calculate backprop errors of all layers:
            dl = self.backprop(ol)
            #Using backprop errors, calculate new weights
            dW = [np.dot(np.transpose(o), dl[0][:,:-1])]
            for i in range(1, len(ol)-1):
                dWi = np.dot(np.transpose(ol[i-1]), dl[i][:,:-1])
                dW.append(dWi)
            dW.append(np.dot(np.transpose(ol[-2]), dl[-1]))

            #If the error improvement drops below a certain tolerance, quit descent
            #if(totimp < tol):
            #    break
            for i in range(len(self.W)):
                self.W[i] += self.beta * dW[i]
            t += 1
            
            err.append(1 - np.sum(comp == np.argmax(ol[-1], axis=1)) / x.shape[0])
            #Update interactive plot
            if(interactive):
                ax.plot(range(1,t+1), err, 'r-', antialiased=True)
                fig.canvas.draw()
            
            sys.stdout.write(str(t) + ' iterations, error rate ' + str(err[t-1]) + ', stepsize %.3e' % self.beta + '\r')
        print('\nDone!')
        if(interactive):
            plt.ioff()
        if(ret):
            return(err)
            
    def normalize(self, data):
        """Normalizes the data to allow for faster convergence of the gradient ascent"""
        return((data - self.mean) / self.variance)
            
    def feedforward(self, o, W=None):
        """Feed-forward given input o and weight matrices W1 and W2."""
        def batchnorm(x, index):
            epsilon = 1e-5
            if(self.afunc == self.sigmoid):
                return(x)
            elif(self.afunc == self.relu):
                mu = np.mean(x, axis=0)
                var = np.var(x, axis=0)
                x_ = (x - mu)/np.sqrt(var + epsilon)
                self.layerparams[index] = [x, x_, mu, var]
                return(x_)# * self.bngamma[index] + self.bnbeta[index])
        
        if(W is None):
            W = self.W
        o1 = batchnorm(self.afunc(np.dot(o, W[0])), 0)
        ol = [np.hstack([o1, np.repeat(1, o1.shape[0])[:,np.newaxis]])]
        for i in range(1, len(W)-1):
            oi = batchnorm(self.afunc(np.dot(ol[-1], W[i])), i)
            ol.append(np.hstack([oi, np.repeat(1, oi.shape[0])[:,np.newaxis]]))
        ol.append(self.afunc(np.dot(ol[-1], W[-1])))
        return(ol)
    
    def backprop(self, ol):
        def batchgrad(dl, index):
            epsilon = 1e-5
            x, x_, mu, var  = self.layerparams[index]
            dl = dl[index]
            dldx_ = self.bngamma[index] * dl
            dldsigma = (-np.sum(np.multiply(dldx_, (x - mu))) / 2) * (1 / np.sqrt(var + epsilon))**3
            dldmu = np.sum(dldx_) * (-1)/var + dldsigma/dl.shape[0] * np.sum(x - mu)
            #Actual value to be backpropagated
            dldx = dldx_/np.sqrt(var + epsilon) + dldsigma * 2 * (x - mu)/dl.shape[0] + dldmu/dl.shape[0]
            dldbeta = np.sum(np.multiply(dl, x_))
            dldgamma = np.sum(dl)
            self.bnbeta[index] += self.beta * dldbeta
            self.bngamma[index] += self.beta * dldgamma
            return(dldx)
        
        dl =[ol[-1] * (1 - ol[-1]) * (self.y - ol[-1])]
        if(self.afunc == self.relu):
            dl[-1] = batchgrad(dl[-1], -1)
        dl.insert(0, ol[-2] * (1 - ol[-2]) * np.dot(dl[0], np.transpose(self.W[-1])))
        for i in reversed(range(len(ol)-2)):
            d = ol[i] * (1 - ol[i]) * np.dot(dl[0][:,:-1], np.transpose(self.W[i+1]))
            if(self.afunc == self.relu):
                d = batchgrad(d, i)
            dl.insert(0, d)
        return(dl)
        
    def classify(self, data):
        """Classifies a set of data vectors, returning a list of the labels assigned"""
        o = np.hstack([self.normalize(data), np.repeat(1, data.shape[0])[:,np.newaxis]])
        ol = self.feedforward(o)
        return([self.labels[x] for x in np.argmax(ol[-1], axis=1)])
    
    def genrdweights(self, c1, c2):
        """Generates a random weight matrix of dimensions (c1,c2)"""
        random = nprd.rand(c1, c2)
        sign = nprd.randint(2, size=(c1, c2))
        sign[np.where(sign == 0)] = -1
        random = np.multiply(random, sign)
        if(self.afunc == self.relu):
            random /= np.sqrt(c1-1)
        return(random)
        
    def sigmoid(self, x):
        """The sigmoidal functinon as defined by the numerically more stable tanh"""
        return(1/2 * (1 + np.tanh(1/2 * x)))
    
    def relu(self, x):
        return(np.maximum(np.zeros(x.shape), x))
        """The rectified linear unit function:"""

import pdb; pdb.set_trace()
#plcounts = [(5,1), (5,2), (10,1), (10,2), (20,1), (40,1)]
plcounts = [(10,1)]
NNC = []
err = []
for (pcount,lcount) in plcounts:
    # %time NNCi = NeuronNetwork()
    err.append(NNCi.train(train, pcount=pcount, lcount=lcount, itlimit=2000, beta=1e-3, afunc='sigmoid'))
    NNC.append(NNCi)
# Out:
# --Return--
# > <ipython-input-27-6e62dbf60fd1>(205)<module>()->None
# -> import pdb; pdb.set_trace()
# (Pdb) c
# Wall time: 0 ns
# 1127 iterations, error rate 0.0606226855027, stepsize 1.000e-03
# Program interrupted. (Use 'cont' to resume).
# > <ipython-input-27-6e62dbf60fd1>(102)train()
# -> for i in range(1, len(ol)-1):
# (Pdb) exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-27-6e62dbf60fd1> in <module>()
#     210 for (pcount,lcount) in plcounts:
#     211     get_ipython().magic('time NNCi = NeuronNetwork()')
# --> 212     err.append(NNCi.train(train, pcount=pcount, lcount=lcount, itlimit=2000, beta=1e-3, afunc='sigmoid'))
#     213     NNC.append(NNCi)
#
# <ipython-input-27-6e62dbf60fd1> in train(self, data, itlimit, tol, pcount, lcount, interactive, ret, beta, afunc)
#     100             #Using backprop errors, calculate new weights
#     101             dW = [np.dot(np.transpose(o), dl[0][:,:-1])]
# --> 102             for i in range(1, len(ol)-1):
#     103                 dWi = np.dot(np.transpose(ol[i-1]), dl[i][:,:-1])
#     104                 dW.append(dWi)
#
# <ipython-input-27-6e62dbf60fd1> in train(self, data, itlimit, tol, pcount, lcount, interactive, ret, beta, afunc)
#     100             #Using backprop errors, calculate new weights
#     101             dW = [np.dot(np.transpose(o), dl[0][:,:-1])]
# --> 102             for i in range(1, len(ol)-1):
#     103                 dWi = np.dot(np.transpose(ol[i-1]), dl[i][:,:-1])
#     104                 dW.append(dWi)
#
# C:\Anaconda3\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      46             return # None
#      47         if event == 'line':
# ---> 48             return self.dispatch_line(frame)
#      49         if event == 'call':
#      50             return self.dispatch_call(frame, arg)
#
# C:\Anaconda3\lib\bdb.py in dispatch_line(self, frame)
#      65         if self.stop_here(frame) or self.break_here(frame):
#      66             self.user_line(frame)
# ---> 67             if self.quitting: raise BdbQuit
#      68         return self.trace_dispatch
#      69
#
# BdbQuit:

# %%
#plcounts = [(5,1), (5,2), (10,1), (10,2), (20,1), (40,1)]
plcounts = [(10,1)]
NNC = []
err = []
for (pcount,lcount) in plcounts:
    # %time NNCi = NeuronNetwork()
    err.append(NNCi.train(train, pcount=pcount, lcount=lcount, itlimit=2000, beta=1e-3, afunc='relu'))
    NNC.append(NNCi)
# Out:
# Wall time: 0 ns
# 63 iterations, error rate 0.836236455905, stepsize 1.000e-03
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:168: RuntimeWarning: overflow encountered in multiply
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:200: RuntimeWarning: invalid value encountered in maximum
# 277 iterations, error rate 0.836236455905, stepsize 1.000e-03
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-65451f7176cd> in <module>()
#       5 for (pcount,lcount) in plcounts:
#       6     get_ipython().magic('time NNCi = NeuronNetwork()')
# ----> 7     err.append(NNCi.train(train, pcount=pcount, lcount=lcount, itlimit=2000, beta=1e-3, afunc='relu'))
#       8     NNC.append(NNCi)
#
# <ipython-input-13-c227acba8264> in train(self, data, itlimit, tol, pcount, lcount, interactive, ret, beta, afunc)
#      99             dl = self.backprop(ol)
#     100             #Using backprop errors, calculate new weights
# --> 101             dW = [np.dot(np.transpose(o), dl[0][:,:-1])]
#     102             for i in range(1, len(ol)-1):
#     103                 dWi = np.dot(np.transpose(ol[i-1]), dl[i][:,:-1])
#
# KeyboardInterrupt:

# %%
matplotlib.rcParams.update({'font.size': 16})
plt.figure(figsize = (18, 10))
for i in range(len(NNC)):
    plt.title('Error rate at each training step for different numbers of perceptrons per hidden layer $p$ and layer-count $l$, (p,l)\n',
             fontsize=20)
    plt.xlabel('# Iterations')
    plt.ylabel('Error rate')
    plt.plot(range(len(err[i])), err[i], '-', antialiased=True, label=str(plcounts[i]))
plt.legend()

# %% [markdown]
# We also take a look at the confusion matrices for the classification of the entire available data (train + test):

# %%
from IPython.display import display, HTML

def runtest(C):
    confusionMat = np.zeros([10, 10], dtype=int)
    for i in range(10):
        data = np.vstack([train[i], test[i]])
        result = C.classify(data)
        for j in range(len(result)):
            confusionMat[i,result[j]] += 1
    print('-The confusion matrix is given by:')
    html = pd.DataFrame(confusionMat,index=C.labels, columns=C.labels).to_html()
    display(HTML(html))
    print('-The error rate is: ' + str(1-sum(np.diag(confusionMat))/np.sum(confusionMat)) + '\n')

# %%
for i in range(len(NNC)):
    print('(p,l) = ' + str(plcounts[i]) + ":\n")
    runtest(NNC[i])
# Out:
# (p,l) = (5, 1):
#
# -The confusion matrix is given by:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1464</td>
#       <td>0</td>
#       <td>10</td>
#       <td>57</td>
#       <td>10</td>
#       <td>3</td>
#       <td>6</td>
#       <td>0</td>
#       <td>3</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>1242</td>
#       <td>4</td>
#       <td>1</td>
#       <td>2</td>
#       <td>0</td>
#       <td>9</td>
#       <td>7</td>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>830</td>
#       <td>39</td>
#       <td>10</td>
#       <td>1</td>
#       <td>21</td>
#       <td>7</td>
#       <td>13</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>0</td>
#       <td>18</td>
#       <td>742</td>
#       <td>2</td>
#       <td>41</td>
#       <td>2</td>
#       <td>6</td>
#       <td>8</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>12</td>
#       <td>15</td>
#       <td>37</td>
#       <td>2</td>
#       <td>685</td>
#       <td>23</td>
#       <td>15</td>
#       <td>23</td>
#       <td>11</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>14</td>
#       <td>0</td>
#       <td>19</td>
#       <td>77</td>
#       <td>21</td>
#       <td>534</td>
#       <td>30</td>
#       <td>8</td>
#       <td>5</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>30</td>
#       <td>12</td>
#       <td>19</td>
#       <td>4</td>
#       <td>11</td>
#       <td>7</td>
#       <td>748</td>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>8</td>
#       <td>14</td>
#       <td>13</td>
#       <td>4</td>
#       <td>734</td>
#       <td>1</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>12</td>
#       <td>3</td>
#       <td>29</td>
#       <td>69</td>
#       <td>7</td>
#       <td>8</td>
#       <td>4</td>
#       <td>12</td>
#       <td>536</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0</td>
#       <td>1</td>
#       <td>3</td>
#       <td>3</td>
#       <td>27</td>
#       <td>21</td>
#       <td>0</td>
#       <td>25</td>
#       <td>11</td>
#       <td>730</td>
#     </tr>
#   </tbody>
# </table>
# -The error rate is: 0.113250161325
#
# (p,l) = (5, 2):
#
# -The confusion matrix is given by:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1504</td>
#       <td>0</td>
#       <td>9</td>
#       <td>19</td>
#       <td>0</td>
#       <td>3</td>
#       <td>15</td>
#       <td>0</td>
#       <td>3</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>1237</td>
#       <td>3</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>9</td>
#       <td>0</td>
#       <td>1</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6</td>
#       <td>6</td>
#       <td>620</td>
#       <td>137</td>
#       <td>1</td>
#       <td>4</td>
#       <td>12</td>
#       <td>22</td>
#       <td>89</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8</td>
#       <td>0</td>
#       <td>76</td>
#       <td>668</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>65</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>16</td>
#       <td>100</td>
#       <td>126</td>
#       <td>1</td>
#       <td>61</td>
#       <td>1</td>
#       <td>11</td>
#       <td>117</td>
#       <td>3</td>
#       <td>416</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>33</td>
#       <td>0</td>
#       <td>138</td>
#       <td>337</td>
#       <td>0</td>
#       <td>8</td>
#       <td>13</td>
#       <td>5</td>
#       <td>176</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>67</td>
#       <td>6</td>
#       <td>20</td>
#       <td>9</td>
#       <td>1</td>
#       <td>0</td>
#       <td>726</td>
#       <td>0</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1</td>
#       <td>2</td>
#       <td>136</td>
#       <td>2</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>322</td>
#       <td>3</td>
#       <td>325</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>11</td>
#       <td>2</td>
#       <td>44</td>
#       <td>111</td>
#       <td>1</td>
#       <td>4</td>
#       <td>13</td>
#       <td>10</td>
#       <td>484</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2</td>
#       <td>4</td>
#       <td>52</td>
#       <td>4</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>121</td>
#       <td>5</td>
#       <td>633</td>
#     </tr>
#   </tbody>
# </table>
# -The error rate is: 0.326414282641
#
# (p,l) = (10, 1):
#
# -The confusion matrix is given by:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1507</td>
#       <td>0</td>
#       <td>11</td>
#       <td>3</td>
#       <td>2</td>
#       <td>4</td>
#       <td>23</td>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>1235</td>
#       <td>4</td>
#       <td>2</td>
#       <td>6</td>
#       <td>2</td>
#       <td>13</td>
#       <td>4</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>13</td>
#       <td>2</td>
#       <td>833</td>
#       <td>17</td>
#       <td>22</td>
#       <td>3</td>
#       <td>15</td>
#       <td>7</td>
#       <td>15</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>11</td>
#       <td>1</td>
#       <td>15</td>
#       <td>777</td>
#       <td>4</td>
#       <td>8</td>
#       <td>0</td>
#       <td>1</td>
#       <td>6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>6</td>
#       <td>6</td>
#       <td>12</td>
#       <td>3</td>
#       <td>771</td>
#       <td>4</td>
#       <td>16</td>
#       <td>4</td>
#       <td>11</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>22</td>
#       <td>4</td>
#       <td>10</td>
#       <td>41</td>
#       <td>10</td>
#       <td>599</td>
#       <td>11</td>
#       <td>5</td>
#       <td>12</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2</td>
#       <td>1</td>
#       <td>13</td>
#       <td>1</td>
#       <td>3</td>
#       <td>12</td>
#       <td>798</td>
#       <td>0</td>
#       <td>4</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>5</td>
#       <td>2</td>
#       <td>2</td>
#       <td>6</td>
#       <td>7</td>
#       <td>1</td>
#       <td>0</td>
#       <td>747</td>
#       <td>2</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>16</td>
#       <td>7</td>
#       <td>21</td>
#       <td>21</td>
#       <td>16</td>
#       <td>26</td>
#       <td>12</td>
#       <td>5</td>
#       <td>582</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2</td>
#       <td>2</td>
#       <td>0</td>
#       <td>9</td>
#       <td>17</td>
#       <td>3</td>
#       <td>0</td>
#       <td>21</td>
#       <td>1</td>
#       <td>766</td>
#     </tr>
#   </tbody>
# </table>
# -The error rate is: 0.0734566573457
#
# (p,l) = (10, 2):
#
# -The confusion matrix is given by:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1503</td>
#       <td>0</td>
#       <td>3</td>
#       <td>14</td>
#       <td>2</td>
#       <td>10</td>
#       <td>20</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>1233</td>
#       <td>1</td>
#       <td>0</td>
#       <td>15</td>
#       <td>3</td>
#       <td>8</td>
#       <td>1</td>
#       <td>2</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10</td>
#       <td>5</td>
#       <td>758</td>
#       <td>62</td>
#       <td>12</td>
#       <td>39</td>
#       <td>17</td>
#       <td>3</td>
#       <td>23</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>14</td>
#       <td>0</td>
#       <td>54</td>
#       <td>703</td>
#       <td>1</td>
#       <td>21</td>
#       <td>3</td>
#       <td>13</td>
#       <td>14</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>13</td>
#       <td>33</td>
#       <td>20</td>
#       <td>9</td>
#       <td>630</td>
#       <td>18</td>
#       <td>11</td>
#       <td>25</td>
#       <td>3</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>38</td>
#       <td>1</td>
#       <td>77</td>
#       <td>91</td>
#       <td>10</td>
#       <td>393</td>
#       <td>35</td>
#       <td>9</td>
#       <td>56</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>4</td>
#       <td>8</td>
#       <td>3</td>
#       <td>6</td>
#       <td>13</td>
#       <td>788</td>
#       <td>0</td>
#       <td>5</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0</td>
#       <td>0</td>
#       <td>7</td>
#       <td>4</td>
#       <td>17</td>
#       <td>1</td>
#       <td>0</td>
#       <td>737</td>
#       <td>1</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>7</td>
#       <td>2</td>
#       <td>21</td>
#       <td>75</td>
#       <td>22</td>
#       <td>26</td>
#       <td>14</td>
#       <td>17</td>
#       <td>518</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2</td>
#       <td>0</td>
#       <td>6</td>
#       <td>8</td>
#       <td>65</td>
#       <td>0</td>
#       <td>0</td>
#       <td>39</td>
#       <td>1</td>
#       <td>700</td>
#     </tr>
#   </tbody>
# </table>
# -The error rate is: 0.143579264358
#
# (p,l) = (20, 1):
#
# -The confusion matrix is given by:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1511</td>
#       <td>1</td>
#       <td>2</td>
#       <td>17</td>
#       <td>2</td>
#       <td>4</td>
#       <td>7</td>
#       <td>0</td>
#       <td>7</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>1241</td>
#       <td>4</td>
#       <td>2</td>
#       <td>7</td>
#       <td>2</td>
#       <td>7</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14</td>
#       <td>2</td>
#       <td>825</td>
#       <td>20</td>
#       <td>14</td>
#       <td>9</td>
#       <td>10</td>
#       <td>20</td>
#       <td>14</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>11</td>
#       <td>1</td>
#       <td>11</td>
#       <td>750</td>
#       <td>7</td>
#       <td>20</td>
#       <td>1</td>
#       <td>11</td>
#       <td>10</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20</td>
#       <td>18</td>
#       <td>13</td>
#       <td>25</td>
#       <td>713</td>
#       <td>6</td>
#       <td>5</td>
#       <td>14</td>
#       <td>23</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>29</td>
#       <td>3</td>
#       <td>5</td>
#       <td>55</td>
#       <td>5</td>
#       <td>591</td>
#       <td>6</td>
#       <td>7</td>
#       <td>12</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>15</td>
#       <td>5</td>
#       <td>5</td>
#       <td>1</td>
#       <td>9</td>
#       <td>14</td>
#       <td>779</td>
#       <td>0</td>
#       <td>6</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>30</td>
#       <td>9</td>
#       <td>7</td>
#       <td>0</td>
#       <td>710</td>
#       <td>6</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>16</td>
#       <td>3</td>
#       <td>1</td>
#       <td>25</td>
#       <td>22</td>
#       <td>17</td>
#       <td>4</td>
#       <td>16</td>
#       <td>601</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>5</td>
#       <td>4</td>
#       <td>0</td>
#       <td>19</td>
#       <td>31</td>
#       <td>4</td>
#       <td>1</td>
#       <td>38</td>
#       <td>11</td>
#       <td>708</td>
#     </tr>
#   </tbody>
# </table>
# -The error rate is: 0.0934609593461
#
# (p,l) = (40, 1):
#
# -The confusion matrix is given by:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1498</td>
#       <td>1</td>
#       <td>2</td>
#       <td>30</td>
#       <td>1</td>
#       <td>3</td>
#       <td>13</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>1247</td>
#       <td>1</td>
#       <td>0</td>
#       <td>4</td>
#       <td>6</td>
#       <td>3</td>
#       <td>5</td>
#       <td>0</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>17</td>
#       <td>11</td>
#       <td>780</td>
#       <td>35</td>
#       <td>14</td>
#       <td>12</td>
#       <td>5</td>
#       <td>29</td>
#       <td>24</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8</td>
#       <td>1</td>
#       <td>22</td>
#       <td>754</td>
#       <td>1</td>
#       <td>17</td>
#       <td>1</td>
#       <td>13</td>
#       <td>5</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20</td>
#       <td>8</td>
#       <td>16</td>
#       <td>1</td>
#       <td>750</td>
#       <td>34</td>
#       <td>7</td>
#       <td>2</td>
#       <td>1</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>19</td>
#       <td>1</td>
#       <td>8</td>
#       <td>55</td>
#       <td>7</td>
#       <td>599</td>
#       <td>18</td>
#       <td>2</td>
#       <td>4</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>16</td>
#       <td>13</td>
#       <td>10</td>
#       <td>2</td>
#       <td>8</td>
#       <td>18</td>
#       <td>763</td>
#       <td>0</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>4</td>
#       <td>4</td>
#       <td>13</td>
#       <td>72</td>
#       <td>5</td>
#       <td>20</td>
#       <td>0</td>
#       <td>649</td>
#       <td>1</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>18</td>
#       <td>24</td>
#       <td>25</td>
#       <td>8</td>
#       <td>48</td>
#       <td>2</td>
#       <td>10</td>
#       <td>562</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1</td>
#       <td>3</td>
#       <td>4</td>
#       <td>7</td>
#       <td>17</td>
#       <td>6</td>
#       <td>0</td>
#       <td>13</td>
#       <td>4</td>
#       <td>766</td>
#     </tr>
#   </tbody>
# </table>
# -The error rate is: 0.100021510002

# %% [markdown]
# Interestingly, the best result within the given number of iterations (2000) is obtained for 10 perceptrons and 1 layer. For higher numbers of layers or of perceptrons, the convergence of the algorithm is slower, which is logical, because more weights have to be calculated in each step. On the other hand, the error curve for $(p, l) = (5, 1)$ typically reaches saturation earlier than for all other error curves for higher perceptron numbers. This could indicate that this number of perceptrons is too low, such that no higher classification rates can be achieved with that given number of perceptrons.
#
# Another remarkable fact is that for higher iteration numbers, the number of wrong classifications features high fluctuations. This instability may stem from overfitting and could suggest that the number of perceptron is innecessarily high.

# %% [markdown]
# # Exercise 2

# %% [markdown]
# Just as in exercise 7, we will try to fit the train the neural network to predict the result of logical functions. As we will see in a minute, this time we wil be able to train the network even for the XOR function obtaining a final error rate of 0.

# %%
anddata = np.array([[1,1]]), np.array([[0,0],[0,1],[1,0]])
ordata = np.array([[1,1],[0,1],[1,0]]), np.array([[0,0]])
xordata = np.array([[0,1],[1,0]]), np.array([[0,0],[1,1]])

# %%
Cand, Cor, Cxor = NeuronNetwork(), NeuronNetwork(), NeuronNetwork()
anderr = Cand.train(anddata, itlimit=1000, pcount=4, beta=1e-1, afunc='sigmoid')
orerr = Cor.train(ordata, itlimit=1000, pcount=4, beta=1e-1)
xorerr = Cxor.train(xordata, itlimit=1000, pcount=4, beta=1e-1)
err = (anderr, orerr, xorerr)
# Out:
# 433 iterations, error rate 0.0, stepsize 1.000e-01
# C:\Anaconda3\lib\site-packages\numpy\core\_methods.py:116: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:165: RuntimeWarning: overflow encountered in multiply
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:166: RuntimeWarning: invalid value encountered in multiply
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:193: RuntimeWarning: invalid value encountered in maximum
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:150: RuntimeWarning: invalid value encountered in true_divide
# 1000 iterations, error rate 0.0, stepsize 1.000e-01
# Done!
# 1000 iterations, error rate 0.25, stepsize 1.000e-01
# Done!
# 1000 iterations, error rate 0.5, stepsize 1.000e-01
# Done!

# %%
fig, subplots = plt.subplots(1, 3, sharey=True, figsize=(18, 6))
for i in range(len(subplots)):
    subplots[i].set_xlim(0,len(err[i]))
    subplots[i].set_ylim(0,1)
    subplots[i].plot(range(1,len(err[i])+1), err[i])

# %%
runtest(anderr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-e218ea7c3a4a> in <module>()
# ----> 1 runtest(anderr)
#
# NameError: name 'runtest' is not defined

# %%
a = np.array([2,2,1])
np.dot(a,a)
# Out:
# 9

# %%
a = [np.ones([3,3]), np.ones([4,4])]

# %%
a
# Out:
# array([[2, 2],
#        [1, 1]])

# %%
a = nprd.random(4)

# %%
a[-1]
# Out:
# 0.75827826630472084
